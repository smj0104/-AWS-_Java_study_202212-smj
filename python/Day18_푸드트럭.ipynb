# %% [markdown]
# ### 전국푸드트럭허가구역표준데이터
#  - 전국/지자체별 푸드트럭 허가구역 갯수
#  - 전국/지자체별 푸드트럭 운영대수

# %%
import numpy as np
import pandas as pd


foodtruck = pd.read_csv('전국푸드트럭허가구역표준데이터.csv', encoding = 'cp949')
foodtruck.head()
print(foodtruck.iloc[1:30, [0,4,5,]])
# Out:
#               허가구역명                                   소재지도로명주소  \
# 1            금양초등학교                        부산광역시 금정구 중앙대로 1755
# 2   부산가톨릭대학교 로사리오광장   부산광역시 금정구 오륜대로 57, 부산가톨릭대학교 로사리오광장 (부곡동)
# 3         호계2차현대홈타운       경기도 안양시 동안구 경수대로 462 (호계동 호계2차현대홈타운)
# 4           안양종합운동장                       경기도 안양시 동안구 평촌대로 389
# 5         은하수 한양아파트     경기도 안양시 동안구 동안로159번길 14 (비산동 은하수한양아파트)
# 6          삼성래미안아파트        경기도 안양시 만안구 안양천서로 311(안양동 삼성래미안아파트)
# 7          한라비발디아파트         경기도 안양시 만안구 박달로 453 (박달동 한라비발디아파트)
# 8            중앙체육공원                           전라북도 익산시 하나로 322
# 9           강화군 화도면                                        NaN
# 10        교동면 난정저수지                                        NaN
# 11            이순신공원                                        NaN
# 12          우포늪생태공원                                        NaN
# 13        남지읍수변생태공원                                        NaN
# 14       낙동강하천공원주차장                                        NaN
# ...

# %%
foodtruck.head()
# Out:
#              허가구역명  장소유형    시도명 시군구명  \
# 0       부산대학교내 장승터     6  부산광역시  금정구
# 1           금양초등학교     6  부산광역시  금정구
# 2  부산가톨릭대학교 로사리오광장     6  부산광역시  금정구
# 3        호계2차현대홈타운     8    경기도  안양시
# 4          안양종합운동장     8    경기도  안양시
#
#                                    소재지도로명주소               소재지지번주소         위도  \
# 0                    부산광역시 금정구 부산대학로 63번길 2      부산광역시 금정구 장전동 40  35.232243
# 1                       부산광역시 금정구 중앙대로 1755   부산광역시 금정구 부곡동 63-27  35.241236
# 2  부산광역시 금정구 오륜대로 57, 부산가톨릭대학교 로사리오광장 (부곡동)       부산광역시 금정구 부곡동 9  35.244677
# 3      경기도 안양시 동안구 경수대로 462 (호계동 호계2차현대홈타운)                   NaN        NaN
# 4                      경기도 안양시 동안구 평촌대로 389  경기도 안양시 동안구 비산동 1023        NaN
#
#            경도  푸드트럭운영대수           허가구역사용료  ... 11월운영시작시각 11월운영종료시각 12월운영시작시각  \
# 0  129.083825       1.0                 0  ...     00:00     00:00     00:00
# 1  129.092025       1.0                 0  ...     00:00     00:00     00:00
# ...
