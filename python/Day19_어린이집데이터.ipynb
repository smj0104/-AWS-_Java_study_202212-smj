# %%
# 전국어린이보호구역표준데이터

# 시설종류벌 cctv 설치 여부 카운트/ 개수
# 광역시도별, 시설종류별 카운트         ~별 = group by
# CCTV 평균 설치대수
# 관할경찰서별 CCTV 대수
# 도로폭 / CCTV 설치대수 상관도

# %%
import numpy as np
import pandas as pd

pd_data = pd.read_csv('전국어린이보호구역표준데이터.csv', encoding = 'cp949')
pd_data
#cctv_data = pd_data.shape[0]
#pd_data['CCTV설치여부'].value_counts()
# Out:
#        시설종류        대상시설명                         소재지도로명주소  \
# 0       유치원  성송초등학교병설유치원             전라북도 고창군 성송면 백토1길 10
# 1      초등학교       성송초등학교             전라북도 고창군 성송면 백토1길 10
# 2       유치원  신림초등학교병설유치원             전라북도 고창군 신림면 동법지길 61
# 3      초등학교       신림초등학교             전라북도 고창군 신림면 동법지길 61
# 4       유치원  심원초등학교병설유치원             전라북도 고창군 심원면 심원로 229
# ...     ...          ...                              ...
# 15051  초등학교       용해초등학교                  전라남도 목포시 포미로 35
# 15052  초등학교       석현초등학교             전라남도 목포시 옥암로186번길 20
# 15053  초등학교       항도초등학교            전라남도 목포시 텃골로33번길 94-8
# 15054  초등학교       애향초등학교             전라남도 목포시 당가두로38번길 23
# 15055  초등학교       남정초등학교  경상남도 창원시 성산구 원이대로878번길 30 (가음동)
#
#                     소재지지번주소         위도          경도      관리기관명   관할경찰서명  \
# 0      전라북도 고창군 성송면 판정리 725  35.356252  126.643542   전라북도 고창군    고창경찰서
# 1      전라북도 고창군 성송면 판정리 725  35.356252  126.643542   전라북도 고창군    고창경찰서
# 2      전라북도 고창군 신림면 법지리 산31  35.494235  126.700198   전라북도 고창군    고창경찰서
# 3      전라북도 고창군 신림면 법지리 산31  35.494235  126.700198   전라북도 고창군    고창경찰서
# 4      전라북도 고창군 심원면 월산리 725  35.525712  126.552392   전라북도 고창군    고창경찰서
# ...                     ...        ...         ...        ...      ...
# 15051      전라남도 목포시 용해동 974  34.818584  126.396995  전라남도 목포시청    목포경찰서
# 15052     전라남도 목포시 석현동 1172  34.814973  126.424503  전라남도 목포시청    목포경찰서
# 15053       전라남도 목포시 상동 264  34.816195  126.415392  전라남도 목포시청    목포경찰서
# 15054     전라남도 목포시 옥암동 1172  34.808847  126.441508  전라남도 목포시청    목포경찰서
# 15055                   NaN  35.210850  128.692116  경상남도 창원시청  창원중부경찰서
#
#       CCTV설치여부  CCTV설치대수 보호구역도로폭     데이터기준일자   제공기관코드     제공기관명
# 0            Y       NaN       9  2022-12-29  4780000  전라북도 고창군
# 1            Y       2.0       9  2022-12-29  4780000  전라북도 고창군
# 2            Y       NaN      18  2022-12-29  4780000  전라북도 고창군
# 3            Y       2.0      18  2022-12-29  4780000  전라북도 고창군
# 4            Y       NaN       9  2022-12-29  4780000  전라북도 고창군
# ...        ...       ...     ...         ...      ...       ...
# 15051        Y       4.0       6  2022-11-30  4800000  전라남도 목포시
# 15052        Y       2.0       6  2022-11-30  4800000  전라남도 목포시
# 15053        Y       3.0       6  2022-11-30  4800000  전라남도 목포시
# 15054        Y       4.0       6  2022-11-30  4800000  전라남도 목포시
# 15055        Y       NaN     NaN  2022-11-25  5670000  경상남도 창원시
#
# [15056 rows x 14 columns]

# %%
lista = pd_data['CCTV설치여부'].value_counts()
# Out:
# Y    11687
# N     3369
# Name: CCTV설치여부, dtype: int64

# %%
child_data = pd_data[['시설종류', 'CCTV설치여부']]
#print(child_data)
c1 = child_data.groupby('시설종류')
c1.sum()
#c2 = child_data.groupby('CCTV설치여부')
# Out:
#                                                     CCTV설치여부
# 시설종류
# 국제학교                                                 YYYYYYY
# 대안학교                                                 NNNNNYN
# 어린이집       YNNNNNNNNNNYNNNNNNNYNYNNNNNNNNNYYYYYYYYYYYYYYY...
# 외국인교육기관                                                    Y
# 외국인학교                                             NYYYNYNYYY
# 유치원        YYYYYYYYYYYNYYYYYYYYYYNYYYNYYYNYYYNNNNNNNNNNNN...
# 초등학교       YYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYNYYYYYYYYYYYYYN...
# 초등학교+어린이집                                                YYY
# 특수학교       NYYYNNYYNYYYYYYYYYYYNYYYNYYYYYYNNNYYYNYYYYYNYY...
# 학원         YYYNNYYYYYYYYNNNNNNNYYYYYYYYYYYYYNYYNNNYNNYYNY...
