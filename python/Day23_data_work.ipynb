# %% [markdown]
# ### 데이터산업의 기술등급별 데이터직무 인력 현황
#
#  * 데이터 직무별 axe 생성
#      * x축 : 시점
#      * y축 : 업종(2개)
#
#  * 하나의 figure에, 총 8개 axe가 바둑판 형식으로 배치되는 형태,( 4col X 2 rows), figure사이즈는 각자 알아서
#  * title 표시

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

pd_data = pd.read_csv('데이터산업의_기술등급별_데이터직무_인력_현황_20230303160532.csv', encoding = 'cp949')
print(pd_data.head())

fig, axes = plt.subplots(4, 2, sharey = True, figsize = (15,7))


import matplotlib.pyplot as plt
import matplotlib

current_font_list = matplotlib.rcParams['font.family']  ## matplotlib이 내부적으로 가진 변숫값 표현

font_path = "C:\Windows\Fonts\HMKMRHD.TTF"
kfont = matplotlib.font_manager.FontProperties(fname=font_path).get_name()

matplotlib.rcParams['font.family']=[kfont]+current_font_list

#fig, axe = plt.subplots()
#fig.suptitle('데이터산업 제목')



for i in range(8):
    print(i, i//4, i%4)
# Out:
#   데이터직무별(1)    시점 기술등급별(1)  데이터 처리 및 관리 솔루션 개발·공급업  데이터 구축 및 컨설팅 서비스업
# 0  데이터 아키텍트  2018        계                     806               4330
# 1  데이터 아키텍트  2019        계                    1202               4355
# 2  데이터 아키텍트  2020        계                    1588               4915
# 3  데이터 아키텍트  2021        계                    2061               6044
# 4   데이터 개발자  2018        계                    4579              16302

# %%
pd_data.columns = ['데이터직무별(1)', '시점','기술등급별(1)', '데이터 처리 및 관리 솔루션 개발·공급업', '데이터 구축 및 컨설팅 서비스업']

print(pd_data.head(12))
print(pd_data.dtypes)
# Out:
#    데이터직무별(1)    시점 기술등급별(1)  데이터 처리 및 관리 솔루션 개발·공급업  데이터 구축 및 컨설팅 서비스업
# 0   데이터 아키텍트  2018        계                     806               4330
# 1   데이터 아키텍트  2019        계                    1202               4355
# 2   데이터 아키텍트  2020        계                    1588               4915
# 3   데이터 아키텍트  2021        계                    2061               6044
# 4    데이터 개발자  2018        계                    4579              16302
# 5    데이터 개발자  2019        계                    4799              17092
# 6    데이터 개발자  2020        계                    5683              18173
# 7    데이터 개발자  2021        계                    7891              21858
# 8   데이터 엔지니어  2018        계                    1616               7528
# 9   데이터 엔지니어  2019        계                    1862               8035
# 10  데이터 엔지니어  2020        계                    2421               8780
# 11  데이터 엔지니어  2021        계                    3276               9866
# 데이터직무별(1)                 object
# ...

# %%
filter1 = pd_data['데이터직무별(1)']=='데이터 아키텍트'
sub_data = pd_data[filter1]

_,axe = plt.subplots()
a = axe.plot(sub_data['시점'], sub_data.iloc[:,3])
b = axe.plot(sub_data['시점'], sub_data.iloc[:,4])
