# %%
import numpy as np

def my_split(s):
    block_start = False
    start_index = 0
    ret_list=[]
    for i, c in enumerate(s):
        if block_start==False:
            if c==',':
                ret_list.append(s[start_index:i])
                start_index=i+1
            elif c=='"':
                block_start=True
                start_index = i
        else:
            if c=='"':
                block_start=False
    if s[-1]!=',':
        ret_list.append(s[start_index:])
    return ret_list

def split_len(data_list):
    len_list=[]
    for e in data_list:
        len_list.append(len(e))
    print(set(len_list))
    if len(set(len_list))>1:
        for i in set(len_list):
            print(i, len_list.count(i))
    return set(len_list)  # set을 반환하도록 일시적으로 바꿈

# %%
csv_data=[]
with open('전국공인중개사사무소표준데이터.CSV') as f:
    for line in f:
        csv_data.append(my_split(line[:-1]))
        
assert len(split_len(csv_data)) == 1

np_data = np.array(csv_data)
for e in enumerate(np_data[0]):
    print(e)
# Out:
# {17}
# (0, '중개사무소명')
# (1, '개설등록번호')
# (2, '개업공인중개사종별구분')
# (3, '소재지도로명주소')
# (4, '소재지지번주소')
# (5, '전화번호')
# (6, '개설등록일자')
# (7, '공제가입유무')
# (8, '대표자명')
# (9, '위도')
# (10, '경도')
# (11, '중개보조원수')
# (12, '소속공인중개사수')
# (13, '홈페이지주소')
# (14, '데이터기준일자')
# (15, '제공기관코드')
# (16, '제공기관명')

# %%
print(np_data[:3])
# Out:
# [['중개사무소명' '개설등록번호' '개업공인중개사종별구분' '소재지도로명주소' '소재지지번주소' '전화번호' '개설등록일자'
#   '공제가입유무' '대표자명' '위도' '경도' '중개보조원수' '소속공인중개사수' '홈페이지주소' '데이터기준일자'
#   '제공기관코드' '제공기관명']
#  ['제일공인중개사사무소' '26710-2015-00005' '공인중개사' '부산광역시 기장군 정관읍 구연로 26' '' ''
#   '2015-01-07' 'Y' '송미경' '' '' '' '' '' '2022-11-25' '3400000'
#   '부산광역시 기장군']
#  ['늘채움부동산공인중개사사무소' '26710-2015-00013' '공인중개사'
#   '"부산광역시 기장군 기장읍 차성남로 91, 1층 일부"' '' '' '2015-01-21' 'Y' '강경미' '' '' ''
#   '' '' '2022-11-25' '3400000' '부산광역시 기장군']]

# %%
btypes = np_data[1:,2]
#print(btypes[:3])
btype_name, btype_count = np.unique(btypes, return_counts=True)  # set
print(btype_count)
print(btype_count*100 / sum(btype_count))
# Out:
# [ 5085 23757   527]
# [17.31417481 80.89141612  1.79440907]

# %%
y_n = np_data[1:, 7]
np.unique(y_n, return_counts = True)
# Out:
# (array(['N', 'Y'], dtype='<U74'), array([   30, 29339], dtype=int64))

# %%
names = np_data[1:, 0]
name_head = []
else_list=[]
for n in names:
    n = n.replace(' ','')
    if '공인중개사' in n:
        name_head.append(n[:n.index('공인중개사')])
    else:
        else_list.append(n)

# %%
s = 'abc공인중개사'
s = s.replace(' ','')
print(s)
# Out:
# abc공인중개사

# %%
#print(name_head[:10])
name, name_count = np.unique(name_head, return_counts = True)
sorted(zip(name, name_count), key = lambda x: x[1], reverse = True)
#print(names[:10])

print(len(else_list))
print(else_list[:10])
# Out:
# 2551
# ['미스터홈즈부동산중개광주장지센터', '삼동역힐스테이트부동산중개', '천일부동산중개사무소', '만세부동산중개', '대일부동산중개사무소', '산들부동산중개사무소', '또또부동산중개사무소', '도시개발부동산중개', '금부동산중개사무소', '바른정부동산중개사무소']

# %%
## 00부동산중개...에서 인기있는 00 이름
popular_name=[]
others=[]
for a in else_list:
    a = a.replace(' ','')   
    if '부동산중개' in a:        # 어떠한 문자열에 특정한 문자열이 들어있는지 확인
        popular_name.append(a[:a.index('부동산중개')])
    else:
        others.append(a)
        
print(popular_name)
# Out:
# ['미스터홈즈', '삼동역힐스테이트', '천일', '만세', '대일', '산들', '또또', '도시개발', '금', '바른정', '대명', '신동', '신동', '신동', '명성', '현대', '황금알', '여주역최고', '얼쑤', '아빠', '남양', '여수', '참진', '유창', '(유)해강', '또바구', '해산', '성실', '웅천에시앙', '영지', '프리모', '유한회사', '삼일', '모두', '미래', '부자', '헤라', '열린', '미스터홈즈', '코스모', '지구', '부자', '신태양', '17', '지장고', '가나', '알짜', '태양', '가가', '뉴부산', '랜드마크', '석우', '청담', '', '진흥', '토라', '지장고', '주식회사시티', '(주)삼동역공장', '리웨어', '금강', '더샵키움', '퍼스트빌', '누리', '벤츠', 'The행복', '센트럴', '옥션', '미스터홈즈', 'SK수', '주식회사송강', '화인', '구상D&C', 'HS', '선진', '사동부영팰리스', '도연', '다올', '대박', '다일', '생생', '정', '미래', '대경', '평화투자', '태양', '지니', '가남', '일성', '목동드림', '목동양지', '행복한', '목동역', '', '부자랜드', '목동역목동', '(주)목동', '초원', '주식회사', '늘푸른', '명문', '고객', '뉴샘', 'FUTURE', '중앙', '서울산킹', '언양1번가', '신라', '주식회사아침', '강', '신세계문경', '주식회사한국', '삼성', '신세계', '심박사', '이룸', '양지', '현대', '신용', '태진', '이음', '(주)혜인건설산업', '성은', '미스터홈즈', '이건', '미스터홈즈', '랜드', '서면토박이', '7춘천세븐', '두리', '남춘천IC', '공간', '서천', '뛰어라', '하늘', '다복', '고창흥덕', '고창노을', '스마트', '대운', '성두', '중앙대', '키움', '소중한'
# ...

# %%
x, x_count = np.unique(popular_name, return_counts=True)
x_result = sorted(zip(x,x_count), key = lambda i : i[1], reverse = True)
x_result[:10]
# Out:
# [('주식회사', 30),
#  ('', 25),
#  ('미스터홈즈', 18),
#  ('미래', 13),
#  ('우리', 12),
#  ('금강', 10),
#  ('부자', 10),
#  ('삼성', 10),
#  ('제일', 10),
#  ('한국', 10)]
