# %%
import numpy as np
import math

x1 = 3
y1 = 10

x2 = 5
y2 = 25

a = math.sqrt((x2 - x`1)** 2)
a = math.sqrt((x2 - x1)**2 + (y2 - y1)**2)  #두 좌표사이의 거리
print(a)   #15.132745950421556

def dist(p1,p2):   #python list version
    print('x:',(p2[0] - p1[0]),(p2[0] - p1[0])**2)
    print('y:',(p2[1] - p1[1]),(p2[1] - p1[1])**2)
    return math.sqrt((p2[0] - p1[0])**2 + (p2[1] - p1[1])**2)

def dist_np(p1,p2):  #(3, 10) ( 5, 25)
    i = p2 - p1
    i = sum(i*i) 
    return math.sqrt(i)

def dist_np2(p1, p2):
    return math.sqrt(sum((p2 - p1)** 2))


b= dist([x1, y1], [x2,y2])
print(b)  #15.132745950421556가 나와야함

c = dist_np(np.array([x1, y1]), np.array([x2, y2]))
print(c)
# Out:
# 15.132745950421556
# x: 2 4
# y: 15 225
# 15.132745950421556
# 15.132745950421556

# %%
car= []
with open('전국자동차정비업체표준데이터.csv')as f:
    for line in f:
        car.append(line[0:150].split(','))

car1= []
print(car[:20])

for a in car[1:]:
    for i, value in enumerate(a[3:]):
        a = value
        
print(value)
# Out:
# [['자동차정비업체명', '자동차정비업체종류', '소재지도로명주소', '소재지지번주소', '위도', '경도', '사업등록일자', '면적', '영업상태', '폐업일자', '휴업시작일자', '휴업종료일자', '운영시작시각', '운영종료시각', '전화번호', '관리기관명', '관리기관전화번호', '데이터기준일자', '제공기관코드', '제공기관명\n'], ['서면카센타', '3', '경상북도 울진군 금강송면 불영계곡로 1684', '', '36.93385095', '129.2462157', '2006-11-27', '650', '1', '', '', '', '09:00', '18:00', '054-781-0744', '경상북도 울진군', '054-789-6636', '2021-10-22', '1613000', '국토교통부\n'], ['주식회사 이에스티', '1', '충청북도 진천군 이월면 이덕로 267', '', '36.9337494', '127.4605018', '2016-02-17', '8821.34', '1', '', '', '', '09:00', '18:00', '043-532-8228', '충청북도 진천군', '043-539-3073', '2021-10-22', '1613000', '국토교'], ['태성산업', '1', '충청북도 충주시 대가주2길 5-1(가주동)', '', '36.93372085', '127.8917746', '2015-06-29', '3837.8', '1', '', '', '', '09:00', '18:00', '043-846-2615', '충청북도 충주시', '043-850-6390', '2021-10-22', '1613000', '국토교통부'], ['현대부분정비', '3', '경상북도 봉화군 춘양면 의양로 95', '', '36.93324577', '128.9135575', '2000-02-07', '246', '1', '', '', '', '09:00', '18:00', '054-672-3721', '경상북도 봉화군', '054-679-6245', '2021-10-22', '1613000', '국토교통부\n'], ['천하카센타', '3', '충청북도 진천군 이월면 진안로 29', '', '36.93313839', '127.4264444', '1998-07-13', '516', '1', '', '', '', '09:00', '18:00', '043-537-8015', '충청북도 진천군', '043-539-3073', '2021-10-22', '1613000', '국토교통부\n'], ['청송종합공업사', '3', '충청남도 천안시 서북구 성환읍 천안대로 2177', '', '36.93306246', '127.133795', '2008-01-10', '129', '1', '', '', '', '09:00', '18:00', '041-582-4202', '충청남도 천안시', '041-521-3620', '2021-10-22', '1613000', '국토교'], ['형제카센타', '3', '충청남도 당진시 송악읍 신평로 1500', '', '36.93297563', '126.7459616', '2000-07-24', '598', '1', '', '', '', '09:00', '18:00', '041-357-6811', '충청남도 당진시', '041-350-3551', '2021-10-22', '1613000', '국토교통부\n'], ['친구카센터', '3', '충청남도 당진시 송악읍 신평로 1500', '', '36.93297563', '126.7459616', '2013-05-27', '598', '1', '', '', '', '09:00', '18:00', '041-357-6411', '충청남도 당진시', '041-350-3551', '2021-10-22', '1613000', '국토교통부\n'], ['둔포점 현대자동차', '3', '충청남도 아산시 둔포면 충무로 1853', '', '36.93260272', '127.043232', '2004-06-28', '714.4', '1', '', '', '', '09:00', '18:00', '041-531-3127', '충청남도 아산시', '041-530-6164', '2021-10-22', '1613000', '국토교통'], ['바름카서비스', '3', '충청북도 음성군 음성읍 예술로 75', '', '36.93241401', '127.683072', '2013-02-19', '2604.46', '1', '', '', '', '09:00', '18:00', '043-872-0951', '충청북도 음성군', '043-871-3894', '2021-10-22', '1613000', '국토교통부\n'], ['이월세차장', '3', '충청북도 진천군 이월면 진안로 1', '', '36.9323396', '127.4292911', '1998-10-21', '304', '1', '', '', '', '09:00', '18:00', '043-536-1382', '충청북도 진천군', '043-539-3073', '2021-10-22', '1613000', '국토교통부\n'], ['현대모터스', '3', '충청북도 음성군 음성읍 시장로 40', '', '36.9315767', '127.6952373', '1999-12-17', '232.2', '1', '', '', '', '09:00', '18:00', '043-872-8272', '충청북도 음성군', '043-871-3894', '2021-10-22', '1613000', '국토교통부\n'], ['명화자동차공업사', '3', '충청남도 아산시 둔포면 둔포중앙로 102', '', '36.93146287', '127.0387029', '2006-12-28', '420', '1', '', '', '', '09:00', '18:00', '041-531-8246', '충청남도 아산시', '041-530-6164', '2021-10-22', '1613000', '국토교통부'], ['유니나카공업사', '3', '충청남도 당진시 송악읍 신평로 1475', '', '36.93127954', '126.7452612', '2001-11-30', '754.6', '1', '', '', '', '09:00', '18:00', '041-357-3161', '충청남도 당진시', '041-350-3551', '2021-10-22', '1613000', '국토교통부'], ['드림모터스', '3', '충청남도 아산시 둔포면 충무로 1814', '', '36.93074827', '127.0390801', '2002-03-04', '907', '1', '', '', '', '09:00', '18:00', '041-533-1119', '충청남도 아산시', '041-530-6164', '2021-10-22', '1613000', '국토교통부\n'], ['기아카클리닉(대산점)', '3', '충청남도 서산시 대산읍 충의로 1839', '', '36.93060453', '126.4405851', '2006-12-08', '114', '1', '', '', '', '09:00', '18:00', '041-681-5547', '충청남도 서산시', '041-660-2245', '2021-10-22', '1613000', '국토교'], ['애니카랜드 음성점', '3', '충청북도 음성군 음성읍 시장로50번길 33', '', '36.93057554', '127.6974914', '2000-02-12', '203.58', '1', '', '', '', '09:00', '18:00', '043-274-4200', '충청북도 음성군', '043-871-3894', '2021-10-22', '1613000', ''], ['부원자동차정비공업사', '3', '충청남도 아산시 둔포면 충무로 1802', '', '36.93056805', '127.037681', '2008-06-25', '157.6', '1', '', '', '', '09:00', '18:00', '041-531-0905', '충청남도 아산시', '041-530-6164', '2021-10-22', '1613000', ...
# 국토

# %%
csv_data=[]
line_no=0
with open('전국자동차정비업체표준데이터.csv')as f:
    for line in f:
        line_no = line_no +1
        if line_no == 2:
            continue
        t = line[:-1].split(',')
        del t[1]
        csv_data.append(t)
        
print(csv_data[3:4])
# Out:
# [['현대부분정비', '경상북도 봉화군 춘양면 의양로 95', '', '36.93324577', '128.9135575', '2000-02-07', '246', '1', '', '', '', '09:00', '18:00', '054-672-3721', '경상북도 봉화군', '054-679-6245', '2021-10-22', '1613000', '국토교통부']]

# %%
#https://coordinates-gps.gosur.com/

p1 = [25.1531, 129.0596]
