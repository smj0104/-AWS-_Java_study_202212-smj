# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib

current_font_list = matplotlib.rcParams['font.family']  ## matplotlib이 내부적으로 가진 변숫값 표현

font_path = "C:\Windows\Fonts\HMKMRHD.TTF"
kfont = matplotlib.font_manager.FontProperties(fname=font_path).get_name()
matplotlib.rcParams['font.family']=[kfont]+current_font_list


pd_data = pd.read_csv('시도별_화재발생_현황_총괄__22.csv', encoding = 'cp949')
print(pd_data.head())
# Out:
#      시점  행정구역별  건수 (건) 사망 (명)  부상 (명)  재산피해(계) (천원)  부동산 (천원)  동산 (천원)  \
# 0  2010  서울특별시    5321     42     188      14503873   5948963  8554910
# 1  2010  부산광역시    2403     19      91      10546785   5580443  4966342
# 2  2010  대구광역시    1923     12      72       4637285   1996359  2640926
# 3  2010  인천광역시    1746     15      65      11614854   5362442  6252412
# 4  2010  광주광역시    1273      7      24       2729570   1358722  1370848
#
#    이재가구수 (가구)  이재민수 (명)
# 0         131       277
# 1          46       126
# 2          62       137
# 3          68       167
# 4          27        71

# %%
df_tips = sns.load_dataset('tips')
sns.displot(data=df_tips, x='total_bill',hue = 'time', kind ='ecdf')
sns.displot(data=df_tips, x='time')  # categorial var.
#sns.catplot(data=df_tips, x='time')
