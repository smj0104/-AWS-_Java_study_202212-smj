# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib

current_font_list = matplotlib.rcParams['font.family']  ## matplotlib이 내부적으로 가진 변숫값 표현

font_path = "C:\Windows\Fonts\HMKMRHD.TTF"
kfont = matplotlib.font_manager.FontProperties(fname=font_path).get_name()
matplotlib.rcParams['font.family']=[kfont]+current_font_list


pd_data = pd.read_csv('시도별_화재발생_현황_총괄__20230307153112.csv', encoding = 'cp949')
print(pd_data.head())
# Out:
#   행정구역별    시점  건수 (건)  사망 (명)  부상 (명)  재산피해(계) (천원)   부동산 (천원)    동산 (천원)  \
# 0    전국  2010   41863     304    1588     266776332  117808118  148968214
# 1    전국  2011   43875     263    1599     256547614  113257928  143289686
# 2    전국  2012   43249     267    1955     289493719  127500018  161993701
# 3    전국  2013   40932     307    1877     434462330  178812680  255649650
# 4    전국  2014   42135     325    1856     405356513  168824616  236531897
#
#    이재가구수 (가구)  이재민수 (명)
# 0        1183      2623
# 1        1158      2417
# 2        1062      2254
# 3        1354      2330
# 4        1178      2374

# %%
#sns.lineplot(data=pd_data, x = '시점', y ='이재민수 (명)',hue = '행정구역별 ')
#sns.displot(data=pd_data, x="시점", hue="행정구역별", multiple="stack", kind="kde")
#sns.displot(data=pd_data, x="시점", hue="사망 (명)", col="행정구역별")

# %%
sns.lineplot(data=pd_data, x = '시점', y ='사망 (명)')
# Out:
# <AxesSubplot: xlabel='시점', ylabel='사망 (명)'>

# %%
fig = plt.figure(figsize=(6.4*3,4.8*2))
left = fig.add_subplot(1,2,1)
left.scatter(pd_data['시점'],pd_data['사망 (명)'], s =100)


#right_top = fig.add_subplot(2,2,2)
#filter1 = pd_data['행정구역별'] != '전국'
#s1 = pd_data.loc[filter1, '사망 (명)'].value_counts()
#right_top.bar(s1.index, s1)
# Out:
# <BarContainer object of 51 artists>

# %%
#print(pd_data['사망 (명)'].dtype)
#pd_data['사망 (명)'].unique()
# Out:
# int64
# array([304, 263, 267, 307, 325, 253, 306, 345, 369, 285, 365, 276,  42,
#         29,  31,  36,  27,  40,  37,  53,  19,  21,  26,  22,  17,  14,
#          9,  13,  16,  12,   7,  11,   8,  18,   5,  15,  10,   1,   3,
#          4,   6,   2,   0,  62,  67,  61,  54,  77,  63,  70,  78,  47,
#        114,  66,  20,  24,  41,  33,  30,  43,  23,  28,  56], dtype=int64)

# %%
f, axs = plt.subplots(1, 2, figsize=(8, 4), gridspec_kw=dict(width_ratios=[4, 3]))
#sns.scatterplot(data=pd_data, x="시점", y="부동산 (천원)", hue="이재가구수 (가구)", ax=axs[0])
sns.scatterplot(data=pd_data, x="시점", y="이재가구수 (가구)", hue="이재민수 (명)", ax=axs[0])
# Out:
# <AxesSubplot: xlabel='시점', ylabel='이재가구수 (가구)'>

# %%
sns.displot(data=pd_data, x="사망 (명)", hue="시점", multiple="stack")
