# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt

with open('iris_ndarray.pickle','rb') as f:
    iris_np = pickle.load(f)
print(iris_np)
sepal_length = iris_np[:,0]
sepal_width = iris_np[:,1]
sepal_ratio = sepal_length / sepal_width
#print(sepal_ratio)


petal_length = iris_np[:,2]
petal_width = iris_np[:,3]
petal_ratio = petal_length / petal_width
#rint(petal_ratio)

print(sepal_ratio.shape)
sepal_ratio_2d = np.expand_dims(sepal_ratio, 1)  #디멘션 하나 추가함 1의 자리에 0을 주면 0번의 자리에 디멘션이 들어감(0, 150)
print(sepal_ratio_2d.shape)

print(petal_ratio.shape)
petal_ratio_2d = petal_ratio[:, np.newaxis] #어느 위치에 넣을 것인지 조절가능
print(petal_ratio_2d.shape)


concate_result = np.concatenate((sepal_ratio_2d, petal_ratio_2d), axis=1)  #축 하나 더하기
print(concate_result.shape)
print(concate_result[:10])
#0번 나누기 1번  을 모아놓은 리스트
#3번 나누기 4번  을 모아놓은 리스트

#print(np.divide.(iris_np))
# Out:
# [[5.1 3.5 1.4 0.2 0. ]
#  [4.9 3.  1.4 0.2 0. ]
#  [4.7 3.2 1.3 0.2 0. ]
#  [4.6 3.1 1.5 0.2 0. ]
#  [5.  3.6 1.4 0.2 0. ]
#  [5.4 3.9 1.7 0.4 0. ]
#  [4.6 3.4 1.4 0.3 0. ]
#  [5.  3.4 1.5 0.2 0. ]
#  [4.4 2.9 1.4 0.2 0. ]
#  [4.9 3.1 1.5 0.1 0. ]
#  [5.4 3.7 1.5 0.2 0. ]
#  [4.8 3.4 1.6 0.2 0. ]
#  [4.8 3.  1.4 0.1 0. ]
#  [4.3 3.  1.1 0.1 0. ]
#  [5.8 4.  1.2 0.2 0. ]
#  [5.7 4.4 1.5 0.4 0. ]
#  [5.4 3.9 1.3 0.4 0. ]
#  [5.1 3.5 1.4 0.3 0. ]
#  [5.7 3.8 1.7 0.3 0. ]
#  [5.1 3.8 1.5 0.3 0. ]
#  [5.4 3.4 1.7 0.2 0. ]
#  [5.1 3.7 1.5 0.4 0. ]
#  [4.6 3.6 1.  0.2 0. ]
#  [5.1 3.3 1.7 0.5 0. ]
#  [4.8 3.4 1.9 0.2 0. ]
#  [5.  3.  1.6 0.2 0. ]
#  [5.  3.4 1.6 0.4 0. ]
#  [5.2 3.5 1.5 0.2 0. ]
#  [5.2 3.4 1.4 0.2 0. ]
#  [4.7 3.2 1.6 0.2 0. ]
#  [4.8 3.1 1.6 0.2 0. ]
#  [5.4 3.4 1.5 0.4 0. ]
#  [5.2 4.1 1.5 0.1 0. ]
#  [5.5 4.2 1.4 0.2 0. ]
#  [4.9 3.1 1.5 0.1 0. ]
#  [5.  3.2 1.2 0.2 0. ]
#  [5.5 3.5 1.3 0.2 0. ]
#  [4.9 3.1 1.5 0.1 0. ]
#  [4.4 3.  1.3 0.2 0. ]
#  [5.1 3.4 1.5 0.2 0. ]
#  [5.  3.5 1.3 0.3 0. ]
#  [4.5 2.3 1.3 0.3 0. ]
#  [4.4 3.2 1.3 0.2 0. ]
#  [5.  3.5 1.6 0.6 0. ]
#  [5.1 3.8 1.9 0.4 0. ]
#  [4.8 3.  1.4 0.3 0. ]
#  [5.1 3.8 1.6 0.2 0. ]
#  [4.6 3.2 1.4 0.2 0. ]
#  [5.3 3.7 1.5 0.2 0. ]
#  [5.  3.3 1.4 0.2 0. ]
#  [7.  3.2 4.7 1.4 1. ]
#  [6.4 3.2 4.5 1.5 1. ]
#  [6.9 3.1 4.9 1.5 1. ]
#  [5.5 2.3 4.  1.3 1. ]
#  [6.5 2.8 4.6 1.5 1. ]
#  [5.7 2.8 4.5 1.3 1. ]
#  [6.3 3.3 4.7 1.6 1. ]
#  [4.9 2.4 3.3 1.  1. ]
#  [6.6 2.9 4.6 1.3 1. ]
#  [5.2 2.7 3.9 1.4 1. ]
#  [5.  2.  3.5 1.  1. ]
#  [5.9 3.  4.2 1.5 1. ]
#  [6.  2.2 4.  1.  1. ]
#  [6.1 2.9 4.7 1.4 1. ]
#  [5.6 2.9 3.6 1.3 1. ]
#  [6.7 3.1 4.4 1.4 1. ]
#  [5.6 3.  4.5 1.5 1. ]
#  [5.8 2.7 4.1 1.  1. ]
#  [6.2 2.2 4.5 1.5 1. ]
#  [5.6 2.5 3.9 1.1 1. ]
#  [5.9 3.2 4.8 1.8 1. ]
#  [6.1 2.8 4.  1.3 1. ]
#  [6.3 2.5 4.9 1.5 1. ]
#  [6.1 2.8 4.7 1.2 1. ]
#  [6.4 2.9 4.3 1.3 1. ]
#  [6.6 3.  4.4 1.4 1. ]
#  [6.8 2.8 4.8 1.4 1. ]
#  [6.7 3.  5.  1.7 1. ]
#  [6.  2.9 4.5 1.5 1. ]
#  [5.7 2.6 3.5 1.  1. ]
#  [5.5 2.4 3.8 1.1 1. ]
#  [5.5 2.4 3.7 1.  1. ]
#  [5.8 2.7 3.9 1.2 1. ]
#  [6.  2.7 5.1 1.6 1. ]
#  [5.4 3.  4.5 1.5 1. ]
#  [6.  3.4 4.5 1.6 1. ]
#  [6.7 3.1 4.7 1.5 1. ]
#  [6.3 2.3 4.4 1.3 1. ]
#  [5.6 3.  4.1 1.3 1. ]
#  [5.5 2.5 4.  1.3 1. ]
#  [5.5 2.6 4.4 1.2 1. ]
#  [6.1 3.  4.6 1.4 1. ]
#  [5.8 2.6 4.  1.2 1. ]
#  [5.  2.3 3.3 1.  1. ]
#  [5.6 2.7 4.2 1.3 1. ]
#  [5.7 3.  4.2 1.2 1. ]
#  [5.7 2.9 4.2 1.3 1. ]
#  [6.2 2.9 4.3 1.3 1. ]
#  [5.1 2.5 3.  1.1 1. ]
#  [5.7 2.8 4.1 1.3 1. ]
#  [6.3 3.3 6.  2.5 2. ]
#  [5.8 2.7 5.1 1.9 2. ]
#  [7.1 3.  5.9 2.1 2. ]
#  [6.3 2.9 5.6 1.8 2. ]
#  [6.5 3.  5.8 2.2 2. ]
#  [7.6 3.  6.6 2.1 2. ]
#  [4.9 2.5 4.5 1.7 2. ]
#  [7.3 2.9 6.3 1.8 2. ]
#  [6.7 2.5 5.8 1.8 2. ]
#  [7.2 3.6 6.1 2.5 2. ]
#  [6.5 3.2 5.1 2.  2. ]
#  [6.4 2.7 5.3 1.9 2. ]
#  [6.8 3.  5.5 2.1 2. ]
#  [5.7 2.5 5.  2.  2. ]
#  [5.8 2.8 5.1 2.4 2. ]
#  [6.4 3.2 5.3 2.3 2. ]
#  [6.5 3.  5.5 1.8 2. ]
#  [7.7 3.8 6.7 2.2 2. ]
#  [7.7 2.6 6.9 2.3 2. ]
#  [6.  2.2 5.  1.5 2. ]
#  [6.9 3.2 5.7 2.3 2. ]
#  [5.6 2.8 4.9 2.  2. ]
#  [7.7 2.8 6.7 2.  2. ]
#  [6.3 2.7 4.9 1.8 2. ]
#  [6.7 3.3 5.7 2.1 2. ]
#  [7.2 3.2 6.  1.8 2. ]
#  [6.2 2.8 4.8 1.8 2. ]
#  [6.1 3.  4.9 1.8 2. ]
#  [6.4 2.8 5.6 2.1 2. ]
#  [7.2 3.  5.8 1.6 2. ]
#  [7.4 2.8 6.1 1.9 2. ]
#  [7.9 3.8 6.4 2.  2. ]
#  [6.4 2.8 5.6 2.2 2. ]
#  [6.3 2.8 5.1 1.5 2. ]
#  [6.1 2.6 5.6 1.4 2. ]
#  [7.7 3.  6.1 2.3 2. ]
#  [6.3 3.4 5.6 2.4 2. ]
#  [6.4 3.1 5.5 1.8 2. ]
#  [6.  3.  4.8 1.8 2. ]
#  [6.9 3.1 5.4 2.1 2. ]
#  [6.7 3.1 5.6 2.4 2. ]
#  [6.9 3.1 5.1 2.3 2. ]
#  [5.8 2.7 5.1 1.9 2. ]
#  [6.8 3.2 5.9 2.3 2. ]
#  [6.7 3.3 5.7 2.5 2. ]
#  [6.7 3.  5.2 2.3 2. ]
#  [6.3 2.5 5.  1.9 2. ]
#  [6.5 3.  5.2 2.  2. ]
#  [6.2 3.4 5.4 2.3 2. ]
#  [5.9 3.  5.1 1.8 2. ]]
# (150,)
# (150, 1)
# (150,)
# (150, 1)
# (150, 2)
# [[ 1.45714286  7.        ]
#  [ 1.63333333  7.        ]
#  [ 1.46875     6.5       ]
#  [ 1.48387097  7.5       ]
#  [ 1.38888889  7.        ]
#  [ 1.38461538  4.25      ]
#  [ 1.35294118  4.66666667]
#  [ 1.47058824  7.5       ]
#  [ 1.51724138  7.        ]
#  [ 1.58064516 15.        ]]

# %%
filter_class0 = iris_np[:,-1]==0.0
iris_np_class0 = iris_np[filter_class0]

filter_class1 = iris_np[:,-1]==1.0
iris_np_class1 = iris_np[filter_class1]


filter_class2 = iris_np[:,-1]==2.0
iris_np_class2 = iris_np[filter_class2]






_,axe = plt.subplots()
axe.set_xlim(0,8)
axe.set_ylim(0,3.0)
axe.scatter(iris_np[:,2], iris_np[:,3])  # scatter = 점으로 나타냄

axe.scatter(iris_np_class0[:,2], iris_np_class0[:,3])

axe.scatter(iris_np_class1[:,2], iris_np_class1[:,3])

axe.scatter(iris_np_class2[:,3], iris_np_class2[:,3])

# %%
print(iris_np[:5])
# Out:
# [[5.1 3.5 1.4 0.2 0. ]
#  [4.9 3.  1.4 0.2 0. ]
#  [4.7 3.2 1.3 0.2 0. ]
#  [4.6 3.1 1.5 0.2 0. ]
#  [5.  3.6 1.4 0.2 0. ]]

# %%
def KNN_predict(iris_np_data, petal_length, petal_width):  # k =5
#(150,2) (2, )
    sub_data = iris_np_data[:, 2:4]
    target_np = np.array([petal_length, petal_width])
    print(sub_data.shape)
    print(target_np.shape)
    #print(target_np - sub_data)
    #print((target_np - sub_data)**2)
    print(  np.sum(  ((target_np - sub_data)**2), axis = 1)  )
    print(np.sqrt( np.sum(  ((target_np - sub_data)**2), axis = 1)  ))
    dist = np.sqrt(  np.sum(  ((target_np - sub_data)**2), axis = 1)  )
    print(dist[:3], len(dist))
    
    class_np = iris_np_data[:,-1]
    print(class_np[:3], len(class_np))
    
    dist_1 = np.expand_dims(dist, 1)
    class_np_1 = np.expand_dims(class_np, 1)
    print(dist_1.shape)
    print(class_np_1.shape)
    r = np.concatenate((dist_1, class_np_1), axis =1)
    print(r.shape)
    r = sorted(r, key = lambda x : x[1], reverse = True)
    print(r[:10])
    #r1 = np.sqrt(((target_np - sub_data)**2.sum())
    #print(r1)

KNN_predict(iris_np, 5.0, 1.5)  # 거리가 가장 가까운 5개 샘플기록 반환
#1차원배열 두개 붙여보기
# Out:
# (150, 2)
# (2,)
# [1.465e+01 1.465e+01 1.538e+01 1.394e+01 1.465e+01 1.210e+01 1.440e+01
#  1.394e+01 1.465e+01 1.421e+01 1.394e+01 1.325e+01 1.492e+01 1.717e+01
#  1.613e+01 1.346e+01 1.490e+01 1.440e+01 1.233e+01 1.369e+01 1.258e+01
#  1.346e+01 1.769e+01 1.189e+01 1.130e+01 1.325e+01 1.277e+01 1.394e+01
#  1.465e+01 1.325e+01 1.325e+01 1.346e+01 1.421e+01 1.465e+01 1.421e+01
#  1.613e+01 1.538e+01 1.421e+01 1.538e+01 1.394e+01 1.513e+01 1.513e+01
#  1.538e+01 1.237e+01 1.082e+01 1.440e+01 1.325e+01 1.465e+01 1.394e+01
#  1.465e+01 1.000e-01 2.500e-01 1.000e-02 1.040e+00 1.600e-01 2.900e-01
#  1.000e-01 3.140e+00 2.000e-01 1.220e+00 2.500e+00 6.400e-01 1.250e+00
#  1.000e-01 2.000e+00 3.700e-01 2.500e-01 1.060e+00 2.500e-01 1.370e+00
#  1.300e-01 1.040e+00 1.000e-02 1.800e-01 5.300e-01 3.700e-01 5.000e-02
#  4.000e-02 2.500e-01 2.500e+00 1.600e+00 1.940e+00 1.300e+00 2.000e-02
#  2.500e-01 2.600e-01 9.000e-02 4.000e-01 8.500e-01 1.040e+00 4.500e-01
#  1.700e-01 1.090e+00 3.140e+00 6.800e-01 7.300e-01 6.800e-01 5.300e-01
#  4.160e+00 8.500e-01 2.000e+00 1.700e-01 1.170e+00 4.500e-01 1.130e+00
#  2.920e+00 2.900e-01 1.780e+00 7.300e-01 2.210e+00 2.600e-01 2.500e-01
#  6.100e-01 2.500e-01 8.200e-01 7.300e-01 3.400e-01 3.380e+00 4.250e+00
#  0.000e+00 1.130e+00 2.600e-01 3.140e+00 1.000e-01 8.500e-01 1.090e+00
#  1.300e-01 1.000e-01 7.200e-01 6.500e-01 1.370e+00 2.210e+00 8.500e-01
#  1.000e-02 3.700e-01 1.850e+00 1.170e+00 3.400e-01 1.300e-01 5.200e-01
#  1.170e+00 6.500e-01 1.700e-01 1.450e+00 1.490e+00 6.800e-01 1.600e-01
#  2.900e-01 8.000e-01 1.000e-01]
# [3.82753184 3.82753184 3.92173431 3.73363094 3.82753184 3.47850543
#  3.79473319 3.73363094 3.82753184 3.76961536 3.73363094 3.64005494
#  3.86264158 4.14366987 4.01621713 3.66878727 3.86005181 3.79473319
#  3.51140997 3.7        3.54682957 3.66878727 4.20594817 3.44818793
#  3.36154726 3.64005494 3.57351368 3.73363094 3.82753184 3.64005494
#  3.64005494 3.66878727 3.76961536 3.82753184 3.76961536 4.01621713
#  3.92173431 3.76961536 3.92173431 3.73363094 3.88973007 3.88973007
#  3.92173431 3.51710108 3.28937684 3.79473319 3.64005494 3.82753184
#  3.73363094 3.82753184 0.31622777 0.5        0.1        1.0198039
#  0.4        0.53851648 0.31622777 1.77200451 0.4472136  1.1045361
#  1.58113883 0.8        1.11803399 0.31622777 1.41421356 0.60827625
#  0.5        1.02956301 0.5        1.17046999 0.36055513 1.0198039
#  0.1        0.42426407 0.72801099 0.60827625 0.2236068  0.2
#  0.5        1.58113883 1.26491106 1.39283883 1.14017543 0.14142136
#  0.5        0.50990195 0.3        0.63245553 0.92195445 1.0198039
#  0.67082039 0.41231056 1.04403065 1.77200451 0.82462113 0.85440037
#  0.82462113 0.72801099 2.03960781 0.92195445 1.41421356 0.41231056
#  1.08166538 0.67082039 1.06301458 1.70880075 0.53851648 1.33416641
#  0.85440037 1.48660687 0.50990195 0.5        0.78102497 0.5
#  0.90553851 0.85440037 0.58309519 1.83847763 2.06155281 0.
#  1.06301458 0.50990195 1.77200451 0.31622777 0.92195445 1.04403065
#  0.36055513 0.31622777 0.84852814 0.80622577 1.17046999 1.48660687
#  0.92195445 0.1        0.60827625 1.36014705 1.08166538 0.58309519
#  0.36055513 0.72111026 1.08166538 0.80622577 0.41231056 1.20415946
#  1.22065556 0.82462113 0.4        0.53851648 0.89442719 0.31622777]
# [3.82753184 3.82753184 3.92173431] 150
# [0. 0. 0.] 150
# (150, 1)
# (150, 1)
# (150, 2)

# %%
#두 점간의 거리 계산 공식  https://jfun.tistory.com/68

x1 = X[0]
x2 = X[49]
display(x1, x2)

distance = np.sqrt(((x1-x2)**2).sum())
distance
