# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib

current_font_list = matplotlib.rcParams['font.family']  ## matplotlib이 내부적으로 가진 변숫값 표현
font_path = "C:\Windows\Fonts\HMKMRHD.TTF"
kfont = matplotlib.font_manager.FontProperties(fname=font_path).get_name()
matplotlib.rcParams['font.family']=[kfont]+current_font_list


pd_data = pd.read_csv('이륜차신고현황_시도별_2.csv', encoding = 'cp949')
print(pd_data.head())
# Out:
#         시점  시도명(1)  시군구(1)  관용 관용.1 관용.2 관용.3  자가용 자가용.1 자가용.2 자가용.3
# 0       시점  시도명(1)  시군구(1)  경형   소형   중형   대형   경형    소형    중형    대형
# 1  2022.01      부산     금정구   9    5   68    2  375  1995  5160   520
# 2  2022.01      부산     기장군   6    5   56    0  280  1395  3307   525
# 3  2022.01      부산      남구   3   10   21    0  488  2375  6850   830
# 4  2022.01      부산      동구   7   29   32    1  206   921  2980   296

# %%
df1 = pd.read_csv('이륜차신고현황_시도별_20230309163418.csv', encoding = 'cp949', header=[0,1])
df1.drop(('시도명(1)','시도명(1)'), axis = 1, inplace = True)
print(df1)
# Out:
#     시군구(1)       시점     계                        관용                  자가용       \
#     시군구(1)       시점    소계   경형    소형    중형   대형  소계  경형  소형  중형 대형    소계   경형
# 0      금정구  2020.01  8325  377  2299  5256  393  99   8  15  73  3  8226  369
# 1      금정구  2020.02  8338  374  2307  5253  404  99   8  15  73  3  8239  366
# 2      금정구  2020.03  8326  378  2307  5248  393  99   8  15  73  3  8227  370
# 3      금정구  2020.04  8357  397  2291  5271  398  92   8   8  73  3  8265  389
# 4      금정구  2020.05  8396  402  2279  5295  420  95  13   8  71  3  8301  389
# ..     ...      ...   ...  ...   ...   ...  ...  ..  ..  ..  .. ..   ...  ...
# 550   부산기타  2022.09    12    0    10     2    0   0   0   0   0  0    12    0
# 551   부산기타  2022.10    12    0    10     2    0   0   0   0   0  0    12    0
# 552   부산기타  2022.11    12    0    10     2    0   0   0   0   0  0    12    0
# 553   부산기타  2022.12    12    0    10     2    0   0   0   0   0  0    12    0
# ...

# %%
fig = plt.figure(figsize=(6.4*3,4.8*2))
left = fig.add_subplot(1,2,1)
left.scatter(pd_data['시점'],pd_data['관용'], s =100)

ilter1 = pd_data['행정구역별'] != '전국'

pd_data.pivot('시점','관용','자가용')
plt.subplot()
# Out:
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_6372\2421468132.py:6: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   pd_data.pivot('시점','관용','자가용')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 6
#       2 left = fig.add_subplot(1,2,1)
#       3 left.scatter(pd_data['시점'],pd_data['관용'], s =100)
# ----> 6 pd_data.pivot('시점','관용','자가용')
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
pd_data.drop(('시도명(1)'), axis = 1 , inplace = True)
pd_data.columns.names('시점')

a = df2.set_index(('시군구(1)'))
b = a.stack(level=0)
b.index.names=['지역','시점']
c =
# Out:
#   Cell In[3], line 1
#     pd_data.pivot("시점", "시도명(1) ", "계
#                                    ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
fig, axs = plt.subplots(2, 2, layout="constrained")
for ax in axs.flat:
    pd_data()
fig.get_layout_engine().set(w_pad=4 / 72, h_pad=4 / 72, hspace=0,wspace=0)
axs.set_title('')
axs.set_labe('')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 fig, axs = plt.subplots(2, 2, layout="constrained")
#       2 for ax in axs.flat:
# ----> 3     pd_data(ax, hide_labels=True)
#       4 fig.get_layout_engine().set(w_pad=4 / 72, h_pad=4 / 72, hspace=0,
#       5                             wspace=0)
#
# TypeError: 'DataFrame' object is not callable
